# %%
import json

file = open('synthetic_dataset_with_time.txt', 'r')
text = file.read()
data = json.loads(text)

# %%
import emip_toolkit as EMTK

# find areas of interest (AOIs) once again
image_path = "./"
image = "synthetic_text.png"
aoi_words = EMTK.find_aoi(image, image_path, level="sub-line")


words_sorted_byline = []

for i in range(len(aoi_lines)):
    words_sorted_byline.append([])
    
for i in range(len(aoi_words)):
    word_line_num = int(aoi_words.at[i, 'name'].strip().split('')[1])
    words_sorted_byline[word_line_num-1].append([aoi_words.at[i, 'x'], aoi_words.at[i, 'y']])
    
error_test, data['robot1'] = correction.erszror_within_line_regression(1, data['robot1'], words_sorted_byline, aoi_lines)


    


# add tokens to AOIs 
file_path = "./"
aois_with_tokens = EMTK.add_tokens_to_AOIs(file_path, image.split(".")[0]+".txt", aoi)
aois_with_tokens.head()


import correction

# find the y coordinate of each line in the text
line_ys = correction.find_lines_Y(aoi)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 15
#      12     words_sorted_byline.append([])
#      14 for i in range(len(aoi_words)):
# ---> 15     word_line_num = int(aoi_words.at[i, 'name'].strip().split('')[1])
#      16     words_sorted_byline[word_line_num-1].append([aoi_words.at[i, 'x'], aoi_words.at[i, 'y']])
#      18 error_test, data['robot1'] = correction.error_within_line_regression(1, data['robot1'], words_sorted_byline, aoi_lines)
#
# ValueError: empty separator

# %%
# Out:
# <module 'drift_algorithms' from '/Users/zehragundogdu/Desktop/CS421/Zehra-CS421project1/drift_algorithms.py'>

# %%
# draw original correct fixations

correction.draw_fixation('synthetic_text.png', data['robot1'].copy())

# %%
# generate noise over the correct trial

error_test = correction.error_within_line_regression(0.05, data['robot1'].copy(), duplicate_fixations=True)
prob, fixations, sortedwords, aoi_lines, duplicate_fixations=True

# draw the trial with added error
correction.draw_fixation('synthetic_text.png', error_test)
